# %%
# %matplotlib inline
import pandas as pd

# %%
po = pd.read_csv("data/po.csv")
po.head()
# Out:
#      COMMODITY                              COMMODITY_DESCRIPTION  \
# 0      2808090                            CABLE, POWER, TYPE XLPE
# 1  34580591001  RESPIRATOR HALFMASK MSA COMFO II BLACK HYCAR R...
# 2  39330570012  BEVERAGE ELECTROLYTE GATORADE POWDER STICK LEM...
# 3        61577  Rubber Stamps, Stamp Pads, Stamp Pad Ink and S...
# 4        73018  Converters: Analog-to-Digital, Digital-to-Analog,
#
#                                 EXTENDED_DESCRIPTION  QUANTITY  \
# 0                                    R17305, 3, 1349      3000
# 1  RC LN____ DEL QTY____ P/F____ B/O____ DEL DATE...         5
# 2  RC LN______QTY DEL______P/F____B/O____DEL DATE...       192
# 3  Two self inkings stamps to endorse checks, ($3...         0
# 4  Distibution auto mation project.   Buyer: Anni...         4
#
#   UNIT_OF_MEASURE UNIT_OF_MEAS_DESC  UNIT_PRICE  ITM_TOT_AM  \
# 0              FT              Foot        0.90     2700.00
# 1              EA              Each       22.79      113.95
# ...

# %%
len(po)
# Out:
# 184406

# %%
po[po.commodity]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-1d28c1b24784> in <module>()
# ----> 1 po[po.commodity]
#
# /Users/ss/anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in __getattr__(self, name)
#    2148                 return self[name]
#    2149             raise AttributeError("'%s' object has no attribute '%s'" %
# -> 2150                                  (type(self).__name__, name))
#    2151
#    2152     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'commodity'

# %%
po.commodity
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-b6499bf5081d> in <module>()
# ----> 1 po.commodity
#
# /Users/ss/anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in __getattr__(self, name)
#    2148                 return self[name]
#    2149             raise AttributeError("'%s' object has no attribute '%s'" %
# -> 2150                                  (type(self).__name__, name))
#    2151
#    2152     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'commodity'

# %%
po.COMMODITY
# Out:
# 0             2808090
# 1         34580591001
# 2         39330570012
# 3               61577
# 4               73018
# 5               03778
# 6               54523
# 7               28796
# 8             2850336
# 9             2857824
# 10        20087930040
# 11        20045100002
# 12            6703310
# 13        21062110001
# 14        47573891009
# 15              72582
# 16              07048
# 17            2852614
# 18        46035100002
# 19              48500
# 20              07051
# 21              20453
# 22              08015
# 23            5707673
# 24        67033205005
# 25              80072
# 26            2801614
# 27            2858049
# 28            2851078
# 29              20477
#              ...
# 184376          47599
# 184377        5407031
# 184378          03121
# 184379    34508410007
# 184380            425
# 184381          27092
# 184382    44572110007
# 184383          72582
# 184384    34572511016
# 184385          71580
# ...

# %%
po.head()
# Out:
#      COMMODITY                              COMMODITY_DESCRIPTION  \
# 0      2808090                            CABLE, POWER, TYPE XLPE
# 1  34580591001  RESPIRATOR HALFMASK MSA COMFO II BLACK HYCAR R...
# 2  39330570012  BEVERAGE ELECTROLYTE GATORADE POWDER STICK LEM...
# 3        61577  Rubber Stamps, Stamp Pads, Stamp Pad Ink and S...
# 4        73018  Converters: Analog-to-Digital, Digital-to-Analog,
#
#                                 EXTENDED_DESCRIPTION  QUANTITY  \
# 0                                    R17305, 3, 1349      3000
# 1  RC LN____ DEL QTY____ P/F____ B/O____ DEL DATE...         5
# 2  RC LN______QTY DEL______P/F____B/O____DEL DATE...       192
# 3  Two self inkings stamps to endorse checks, ($3...         0
# 4  Distibution auto mation project.   Buyer: Anni...         4
#
#   UNIT_OF_MEASURE UNIT_OF_MEAS_DESC  UNIT_PRICE  ITM_TOT_AM  \
# 0              FT              Foot        0.90     2700.00
# 1              EA              Each       22.79      113.95
# ...

# %%
len(po[po.QUANTITY == 3000])
# Out:
# 248

# %%
po.groupby(['UNIT_OF_MEASURE']).size().plot()

# %%
# %%time 
po[po.QUANTITY == 3000]
# Out:
# CPU times: user 4.11 ms, sys: 711 µs, total: 4.82 ms
# Wall time: 3.96 ms
#           COMMODITY                              COMMODITY_DESCRIPTION  \
# 0           2808090                            CABLE, POWER, TYPE XLPE
# 3054        2808089                                    CABLE, TYPE XLP
# 3683        2803032                                     CABLE, CONTROL
# 4023        2808089                                    CABLE, TYPE XLP
# 5813        2808090                            CABLE, POWER, TYPE XLPE
# 5942        2808089                                    CABLE, TYPE XLP
# 6927        2808090                            CABLE, POWER, TYPE XLPE
# 7562    67058108015  WASHER METER RUBBER 3/4IN I.D.INSIDE DIA.X1-1/...
# 7950          28016  Bare Cables and Wires: Type ACSR, Bare Copper,...
# 7963        2808089                                    CABLE, TYPE XLP
# 9066        2808088                                    CABLE, TYPE URD
# ...

# %%
po.order('QUANTITY').set_index(['QUANTITY'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-34-0ed1eff97fc5> in <module>()
# ----> 1 po.order('QUANTITY').set_index(['QUANTITY'])
#
# /Users/ss/anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in __getattr__(self, name)
#    2148                 return self[name]
#    2149             raise AttributeError("'%s' object has no attribute '%s'" %
# -> 2150                                  (type(self).__name__, name))
#    2151
#    2152     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'order'

# %%
# %%time
po[po.QUANTITY < 5000]
# Out:
# CPU times: user 64.3 ms, sys: 10.1 ms, total: 74.4 ms
# Wall time: 76.5 ms
#           COMMODITY                              COMMODITY_DESCRIPTION  \
# 0           2808090                            CABLE, POWER, TYPE XLPE
# 1       34580591001  RESPIRATOR HALFMASK MSA COMFO II BLACK HYCAR R...
# 2       39330570012  BEVERAGE ELECTROLYTE GATORADE POWDER STICK LEM...
# 3             61577  Rubber Stamps, Stamp Pads, Stamp Pad Ink and S...
# 4             73018  Converters: Analog-to-Digital, Digital-to-Analog,
# 5             03778          Souvenirs: Promotional, Advertising, etc.
# 6             54523      Impact Tools, Air Powered (Not Road Building)
# 7             28796  Wire and Cable, Electronic: Audio, Coaxial, Ho...
# 8           2850336                               ARRESTERS, LIGHTNING
# 9           2857824                    BRACES AND BRACKETS, STRUCTURAL
# 10      20087930040      TROUSERS TACTICAL 65/35 POLY RAYON MENS 33X33
# ...
